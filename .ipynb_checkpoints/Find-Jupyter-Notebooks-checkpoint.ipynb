# %% [markdown]
# # Using locate to make a list of all Jupyter Notebooks

# %%
import os
os.getcwd()
# Out:
# '/home/jack/Desktop/NXGIN'

# %%
os.chdir('/home/jack/Desktop/NXGIN')

# %%
# !locate *.ipynb >>/home/jack/Desktop/NXGIN/NoteBook.list

# %% [markdown]
# ## Locate a notebook by a term in the title

# %%
#count total notebooks
count = 0
lines = open("NoteBook.list").readlines()
for line in lines:
    line = line.replace("\n","")
    count = count +1
print count
# Out:
# 1871

# %%
lines = open("NoteBook.list").readlines()
SEARCH = raw_input("SEARCH: ")
for line in lines:
    line = line.replace("\n","")
    if SEARCH in line:
        print line
# Out:
# SEARCH: post
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/BIND01/TitleandSigntitlenpost.py151693682993.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-Graphics/TitleandSigntitlenpost.py152695701516152695701516.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-Graphics/randpalettepost152584808569152584808569.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-Graphics/.ipynb_checkpoints/TitleandSigntitlenpost.py152695701516152695701516-checkpoint.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-TEMP/TitleandSigntitlenpost.py152205289834152205289834.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-Twitter/TitleandSigntitlenpost.py152695701516152695701516.ipynb
# /mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/JupyterNotebook-Twitter/twitterpost-font-stuff152491168618152491168618.ipynb
# ...

# %%
# !mv /home/jack/Downloads/dream.html .

# %%
import Key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-f66fd6ff84df> in <module>()
# ----> 1 import Key
#
# ImportError: No module named Key

# %%
/home/jack/Desktop/JupyterNotebook-CharRnn/scrape/PythonMaster-scrape-twitter.ipynb
/home/jack/Desktop/JupyterNotebook-CharRnn/scrape/.ipynb_checkpoints/PythonMaster-scrape-twitter-checkpoint.ipynb

PATH="/mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/"

PATH+"JupyterNotebook-Twitter/misc_twitter_stuff150647775968150647775968.ipynb"
PATH+"JupyterNotebook-Twitter/twitterpost-font-stuff152491168618152491168618.ipynb"
PATH+"PROCESSING/processing/.ipynb_checkpoints/65twitterjunk-checkpoint.ipynb"

"/mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/BIND01/TitleandSigntitlenpost.py151693682993.ipynb"
PATH+"JupyterNotebook-Graphics/TitleandSigntitlenpost.py152695701516152695701516.ipynb"
PATH+"JupyterNotebook-Graphics/randpalettepost152584808569152584808569.ipynb"
PATH+"JupyterNotebook-TEMP/TitleandSigntitlenpost.py152205289834152205289834.ipynb"
PATH+"JupyterNotebook-Twitter/TitleandSigntitlenpost.py152695701516152695701516.ipynb"
PATH+"JupyterNotebook-Twitter/twitterpost-font-stuff152491168618152491168618.ipynb"

# %%
# !locate key.py
# Out:
# /home/jack/.vscode/extensions/ms-python.python-2018.8.0/pythonFiles/experimental/ptvsd/ptvsd/_vendored/pydevd/_pydev_bundle/pydev_monkey.py
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py26-python/lib/python2.7/site-packages/setuptools/monkey.py
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py26-python/lib/python2.7/site-packages/setuptools/monkey.pyc
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py27-python/lib/python2.7/site-packages/setuptools/monkey.py
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py27-python/lib/python2.7/site-packages/setuptools/monkey.pyc
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py33-python/lib/python2.7/site-packages/setuptools/monkey.py
# /home/jack/Desktop/Ubuntu16.04/misc-stuff/protobuf-3.2.0/python/.tox/py33-python/lib/python2.7/site-packages/setuptools/monkey.pyc
# ...

# %%
import sys
sys.path.insert(0,"/home/jack/hidden")
import key
help(key)
# Out:
# Help on module key:
#
# NAME
#     key
#
# FILE
#     /home/jack/hidden/key.py
#
# FUNCTIONS
#     twiter()

# %%
# !rm TitleandSigntitlenpost.ipynb

# %%
PATH="/mnt/40ec525c-34bc-44ef-99c8-53f5524ad88b/home/jack/Desktop/"
f = open(PATH+"JupyterNotebook-Graphics/TitleandSigntitlenpost.py152695701516152695701516.ipynb","r").readlines()
f0 = open("TitleandSigntitlenpost.ipynb", "a")
for line in f:
    f0.write(line)
f0.close()
