# %% [markdown]
# # Manipulating Images Using Numpy Arrays

# %% [markdown]
# <a id ="HOME"></a>
# <a href="#open">Open an Image With CV2</a>&nbsp;&nbsp;&nbsp;|&nbsp;&nbsp;&nbsp;<a href="#save">Save an Image With CV2</a>&nbsp;&nbsp;&nbsp;|&nbsp;&nbsp;&nbsp;<a href="#interpolation">Interpolation Methods</a><br />

# %%
# !ls ~/.jupyter
# !ls ~/.ipython/profile_default
# Out:
# db  history.sqlite  history.sqlite-journal  log  pid  security	startup

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
c = get_config()
~/.ipython/profile_default/ipython_config.py
# Run all nodes interactively
c.InteractiveShell.ast_node_interactivity = "all"

# %%
# imports and basic non-caffe notebook setup
from cStringIO import StringIO
import numpy as np
import scipy.ndimage as nd
import PIL.Image
from IPython.display import clear_output, Image, display
def showarray(a, fmt='jpeg'):
    a = np.uint8(np.clip(a, 0, 255))
    f = StringIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))

# %%
# !ls images
# Out:
# 003.jpg     man.jpg    seq	     SStest2.png       ztextbacktmp.png
# island.jpg  NewFolder  SStest2L.jpg  testingagain.jpg

# %%
img = np.float32(PIL.Image.open('images/island.jpg'))
showarray(img)

# %% [markdown]
# ## Flip an Image Horizontal

# %%
flipim = np.flip(img, 1)
showarray(flipim)

# %% [markdown]
# ## Flip an image Verticle

# %%
flipim = np.flip(img, 0)
showarray(flipim)

# %%
print np.shape(img)
# Out:
# (640, 640, 3)

# %%
rsize = np.resize(img,(320,320, 3))
showarray(rsize)

# %%
import cv2
help(cv2.resize)
# Out:
# Help on built-in function resize:
#
# resize(...)
#     resize(src, dsize[, dst[, fx[, fy[, interpolation]]]]) -> dst

# %%
import cv2
import numpy as np
img = cv2.imread('images/island.jpg')
res = cv2.resize(img, dsize=(250, 250), interpolation=cv2.INTER_CUBIC)
showarray(res)

# %% [markdown]
# filein = open("cv2.info", "r").read()
# lines = filein.split("\n")
# for line in lines:
#      print line

# %%
filein = open("cv2.info", "r").read()
LINZ = []
lines = filein.split("\n")
search = raw_input("SEARCH: ")
count = 0
for line in lines:
    count = count+1
    if search in line:
        print line
# Out:
# SEARCH: interpolation
#         convertMaps(map1, map2, dstmap1type[, dstmap1[, dstmap2[, nninterpolation]]]) -> dstmap1, dstmap2
#         remap(src, map1, map2, interpolation[, dst[, borderMode[, borderValue]]]) -> dst
#         resize(src, dsize[, dst[, fx[, fy[, interpolation]]]]) -> dst

# %% [markdown]
# <a id="interpolation"></a>
# ## Interpolation Methods
# <a href="#HOME">HOME</a>

# %%
interpolation methods:
INTER_NEAREST - a nearest-neighbor interpolation
INTER_LINEAR - a bilinear interpolation (used by default)
INTER_AREA - resampling using pixel area relation. It may be a preferred method for image decimation,
             as it gives moire’-free results. But when the image is zoomed, it is similar to the INTER_NEAREST method.
INTER_CUBIC - a bicubic interpolation over 4x4 pixel neighborhood
INTER_LANCZOS4 - a Lanczos interpolation over 8x8 pixel neighborhood
REF:
    http://tanbakuchi.com/posts/comparison-of-openv-interpolation-algorithms/

# %%
import cv2
import numpy as np
img = cv2.imread('images/island.jpg')
res = cv2.resize(img, dsize=(250, 250), interpolation=cv2.INTER_CUBIC)
showarray(res)

# %%
I am sure the off colors were noticed above. That is because the nature of cv2 is to convert images to BGR 
In order to view the original colors convert the image back to back to RGB 'cv2.COLOR_BGR2RGB'

# %%
view = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
showarray(view)

# %% [markdown]
# <a id = "save"></a>
# ## Save a numpy/cv2 image array / object
# <a href ="#HOME">HOME</a>

# %%
cv2.imwrite("SAVED-image.jpg", view)
# Out:
# True

# %% [markdown]
# <a id = "open"></a>
# # 3 View an image
# <a href ="#HOME">HOME</a>

# %%
saved = cv2.imread("SAVED-image.jpg")
showarray(saved)
